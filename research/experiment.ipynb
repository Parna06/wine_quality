# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\mepar\\OneDrive\\Desktop\\projects\\wine_quality\\research'

# %%
print("Current directory:", os.getcwd())
# Out:
# Current directory: c:\Users\mepar\OneDrive\Desktop\projects\wine_quality\research

# %%
targer_dir = r"C:\Users\mepar\OneDrive\Desktop\projects\wine_quality"
os.chdir(targer_dir)

# %%
print("Current directory:", os.getcwd())
# Out:
# Current directory: C:\Users\mepar\OneDrive\Desktop\projects\wine_quality

# %%
# !pip install pandas

# %%
# !pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
DATA_PATH = "data\winequality-red.csv"
wines = pd.read_csv(DATA_PATH)

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wines.shape
# Out:
# (1599, 12)

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wines.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.57.0-cp38-cp38-win_amd64.whl.metadata (104 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
# Using cached contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Data visualization

# %%
import matplotlib.pyplot as plt
wines.hist(bins=50, figsize=(20,15), color='blue')
plt.show()

# %%
sns.catplot(x='quality', data=wines, kind='count', hue='quality')

# %%
plot = plt.figure(figsize=(10,10))
sns.barplot(x='quality', y='volatile acidity', data=wines, hue='quality')
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
plot = plt.figure(figsize=(10,10))
sns.barplot(x='quality', y='citric acid', data=wines, hue='quality')
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
plot = plt.figure(figsize=(10,10))
sns.barplot(x='quality', y='residual sugar', data=wines, hue='quality')
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
correlation = wines.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
x = wines.iloc[:,0:-1]

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Label Binarization

# %%
y = wines.iloc[:,1].apply(lambda y_value: 1 if y_value>=7 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: volatile acidity, Length: 1599, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_peed = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
def evaluate_model(actual,pred):
    rmse = np.sqrt(mean_squared_error(actual,pred))
    mae = mean_absolute_error(actual,pred)
    r2 = r2_score(actual,pred)
    accuracy = accuracy_score(actual, pred)
    return rmse, mae, r2, accuracy

# %%
(rmse, mae, r2, accuracy) = evaluate_model(y_test,y_peed)

# %%
print("rmse: ", rmse)
print("mae: ", mae)
print("r2 Score: ", r2)
print("accuracy_score: ", accuracy)
# Out:
# rmse:  0.0
# mae:  0.0
# r2 Score:  1.0
# accuracy_score:  1.0
